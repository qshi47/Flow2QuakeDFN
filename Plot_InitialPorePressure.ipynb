# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cuboids = np.loadtxt("CuboidCoupling/Input_Cuboids.txt", delimiter=",", skiprows=1)

# %%
cuboids_centers = cuboids[:, [1,2,3]]

# %%
data = np.loadtxt("CuboidCoupling/Input_PorePressure.txt", usecols = range(1, 5), delimiter=",")

# %%
time = data[0, :]
pressure = data[1:, :]
print(pressure.shape)
# Out:
# (1600, 4)

# %%
plt.scatter(cuboids_centers[:,0],cuboids_centers[:,1], c = pressure[:,-1], cmap='RdBu_r', vmin = 0, vmax = 10e6)
plt.colorbar(label='Pore Pressure (MPa)')
